# %% [markdown]
# # ![](https://img.webmd.com/dtmcms/live/webmd/consumer_assets/site_images/articles/health_tools/did_you_know_this_could_lead_to_heart_disease_slideshow/493ss_thinkstock_rf_heart_illustration.jpg) Visualizations...

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd #importing libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Dataset

# %% [markdown]
# datasource : https://chronicdata.cdc.gov/Heart-Disease-Stroke-Prevention/National-Vital-Statistics-System-NVSS-National-Car/kztq-p2jf

# %%
stroke = pd.read_csv('./datasets/stroke.csv') #importing the dataset

# %%
stroke.head()
# Out:
#    Year LocationAbbr LocationDesc                 Category  \
# 0  2013           IL     Illinois  Cardiovascular Diseases
# 1  2000           MT      Montana  Cardiovascular Diseases
# 2  2001           KS       Kansas  Cardiovascular Diseases
# 3  2004           AL      Alabama  Cardiovascular Diseases
# 4  2002           OH         Ohio  Cardiovascular Diseases
#
#                           Topic  \
# 0                        Stroke
# 1  Major Cardiovascular Disease
# 2                        Stroke
# 3                        Stroke
# 4  Major Cardiovascular Disease
#
#                                            Indicator  Data_Value_Type  \
# 0  Rate of ischemic stroke mortality among US adu...                0
# 1  Rate of major cardiovascular disease mortality...                0
# 2  Rate of ischemic stroke mortality among US adu...                1
# 3  Rate of ischemic stroke mortality among US adu...                1
# ...

# %% [markdown]
# ### Distribution

# %%
sns.set() # for style
 
ax = sns.distplot(stroke["Data_Value"],label="Heart Disease Data");
ax.set(xlabel = "Data Value"); #labelling the axis
plt.title("Data Value"); # for histogram title
plt.legend(); # for label
# Out:
# c:\users\loaner1\anaconda3\envs\dsi\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Data Value is positively Skewed and it means that its Mean will be greater than its Median

# %%
sns.set() # for style
 
ax = sns.distplot(stroke["AvgConfidenceLimit"],label="Heart Disease Data");
ax.set(xlabel = "Confidence Limit"); #labelling the axis
plt.title("Confidence Limit"); # for histogram title
plt.legend(); # for label
# Out:
# c:\users\loaner1\anaconda3\envs\dsi\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The Avg Confidence Limit is Negatively Skewed

# %%
sns.set() # for style
 
ax = sns.distplot(stroke["HighConfidenceLimit"],label="Heart Disease Data");
ax.set(xlabel = "High Confidence Limit"); #labelling the axis
plt.title("High Confidence Limit"); # for histogram title
plt.legend(); # for label
# Out:
# c:\users\loaner1\anaconda3\envs\dsi\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The High Confidence Limit is positively skewed

# %%
sns.set() # for style
 
ax = sns.distplot(stroke["LowConfidenceLimit"],label="Heart Disease Data");
ax.set(xlabel = "Low Confidence Limit"); #labelling the axis
plt.title("Low Confidence Limit"); # for histogram title
plt.legend(); # for label
# Out:
# c:\users\loaner1\anaconda3\envs\dsi\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The Low Confidence Limit is positively skewed

# %% [markdown]
# ### Scatter Plots

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x= 'LowConfidenceLimit', #creating a scatter plot
                y= 'HighConfidenceLimit',
                 hue='Topic',
                data=stroke)
ax.set(xlabel="Low Confidence Limit", ylabel = "High Confidence Limit") #labelling the axis
# Out:
# [Text(0.5, 0, 'Low Confidence Limit'), Text(0, 0.5, 'High Confidence Limit')]

# %% [markdown]
# In this scatter plot we can see the trend of different diseases in terms of High and Low confidence Limit from Stroke to Heart Failure. Each Disease values are described in a different color

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x= 'LowConfidenceLimit', #creating a scatter plot
                y= 'HighConfidenceLimit',
                 hue='Break_Out_Category',
                data=stroke)
ax.set(xlabel="Low Confidence Limit", ylabel = "High Confidence Limit") #labelling the axis
# Out:
# [Text(0.5, 0, 'Low Confidence Limit'), Text(0, 0.5, 'High Confidence Limit')]

# %% [markdown]
# In this scatter plot we can see the trend of different Categories in terms of High and Low confidence Limit from Age to Gender. Each Category values are described in a different color

# %%
ax = sns.scatterplot(x= 'Data_Value', #creating a scatter plot
                y= 'HighConfidenceLimit',
                 hue='Topic_Stroke',
                data=stroke)
ax.set(xlabel="Data Value", ylabel = "High Confidence Limit") #labelling the axis
# Out:
# [Text(0.5, 0, 'Data Value'), Text(0, 0.5, 'High Confidence Limit')]

# %% [markdown]
# In this scatter plot we can see the trend of Stroke Disease in terms of Data Value and High confidence Limit . "0" means that the person does not have a Stroke and "1" means He/She has it.

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x= 'Data_Value', #creating a scatter plot
                y= 'HighConfidenceLimit',
                 hue='Topic',
                data=stroke)
ax.set(xlabel="Data Value", ylabel = "High Confidence Limit") #labelling the axis
# Out:
# [Text(0.5, 0, 'Data Value'), Text(0, 0.5, 'High Confidence Limit')]

# %% [markdown]
# In this scatter plot we can see the trend of different Diseases in terms of Data Value and High confidence Limit from Stroke to Heart Failure. Each Disease values are described in a different color

# %% [markdown]
# ### Correlation

# %%
plt.figure(figsize=(12,12)) #fixing the chart size
sns.heatmap(stroke[['Data_Value','AvgConfidenceLimit','HighConfidenceLimit','LowConfidenceLimit','Break_Out_Category_Age','Break_Out_Category_Gender','Break_Out_Category_Overall','Break_Out_Category_Race']].corr(),annot=True, cmap="RdBu_r");
#this heatmap explains the correlation between the variables

# %% [markdown]
# ### Line Chart

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x= 'Year',
                y= 'Data_Value',
             hue = 'Topic',
                data=stroke);

# %% [markdown]
# In this line plot we can see the trend of different Diseases in terms of Data Value and Year from Stroke to Heart Failure. Each Disease values are described in a different color

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x= 'Year',
                y= 'Data_Value',
             hue = 'Break_Out_Category',
                data=stroke);

# %% [markdown]
# In this line plot we can see the trend of different Diseases in terms of Data Value and Year from Age to Gender. Each Category values are described in a different color

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x= 'Year',
                y= 'HighConfidenceLimit',
             hue = 'Break_Out_Category',
                data=stroke);

# %% [markdown]
# In this line plot we can see the trend of different Category in terms of High Confidence Limit and Year from Age to Gender. Each Category values are described in a different color

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x= 'Year',
                y= 'LowConfidenceLimit',
             hue = 'Break_Out_Category',
                data=stroke);

# %% [markdown]
# In this line plot we can see the trend of different Category in terms of Low Confidence Limit and Year from Age to Gender. Each Category values are described in a different color
